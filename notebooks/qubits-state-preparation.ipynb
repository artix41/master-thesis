# %% [markdown]
# # Purity State Preparation for Qubits
# Quantum Neural Network (QNN) that prepare a dataset of density matrices with uniform purity

# %%
import os
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
from IPython.display import clear_output

from pyquil import Program
from pyquil.gates import *
from pyquil.api import WavefunctionSimulator

import qutip

from scipy.optimize import minimize

os.chdir("..")
from create_purity_dataset import generate_density_matrices

# %%
# %load_ext autoreload
# %autoreload 2

# %%
np.random.seed(42)

# %% [markdown]
# ## Constants

# %% [markdown]
# ### Dataset

# %%
data_folder = "data_qubits"

n_qubits_rho = 1
n_qubits_psi = n_qubits_rho * 2 # for purification

size_hilbert = 2**n_qubits_rho

n_samples = 400

# %% [markdown]
# ### Training

# %%
functional_reg = 1

# %% [markdown]
# ## Creating the dataset

# %%
rhos, purities = generate_density_matrices(n_samples, size_hilbert)
# Out:
# Generate density matrices...
# (400, 2, 2)

# %% [markdown]
# ## State Preparation Network

# %%
wf_sim = WavefunctionSimulator()

# %% [markdown]
# ### Network

# %%
def sp_network(params):
    circuit = Program()
    circuit += RZ(params[0], 0)
    circuit += RY(params[1], 0)
    circuit += RZ(params[2], 0)
    circuit += RZ(params[3], 1)
    circuit += RY(params[4], 1)
    circuit += RZ(params[5], 1)
    circuit += CNOT(1,0)
    circuit += RZ(params[6], 0)
    circuit += RY(params[7], 1)
    circuit += CNOT(0,1)
    circuit += RY(params[8], 1)
    circuit += CNOT(1,0)
    circuit += RZ(params[9], 0)
    circuit += RY(params[10], 0)
    circuit += RZ(params[11], 0)
    circuit += RZ(params[12], 1)
    circuit += RY(params[13], 1)
    circuit += RZ(params[14], 1)

    return circuit

# %% [markdown]
# ### Parameters

# %%
params = np.random.normal(size=15, scale=0.01)

# %% [markdown]
# ### Output

# %%
def partial_trace(state):
    qstate = state[0] * qutip.states.ket([0,0]) \
             + state[1] * qutip.states.ket([0,1]) \
             + state[2] * qutip.states.ket([1,0]) \
             + state[3] * qutip.states.ket([1,1]) 
    rho_output = np.array(qstate.ptrace(1).data.todense())
    return rho_output

# %%
def get_rho(params):
    circuit = sp_network(params)
    state = list(wf_sim.wavefunction(circuit))
    rho_output = partial_trace(state)
    
    return rho_output

# %% [markdown]
# ### Cost and optimizer

# %%
def purity_fct(rho):
    return np.real(np.trace(rho @ rho))

# %%
def purity_mse(rho_output, rho_input):
    return np.mean((purity_fct(rho_output) - purity_fct(rho_input))**2)

# %%
def trace_distance(rho1, rho2):
    return np.mean(np.real(np.linalg.eigvalsh(rho1 - rho2)**2))

# %%
def cost(params, rho_input):
    rho_output = get_rho(params)
    
    return trace_distance(rho_output, rho_input) + functional_reg * purity_mse(rho_output, rho_input)

# %%
cost(params, rhos[0])
# Out:
# 0.520065817038432

# %%
minimize(lambda params: cost(params, rhos[0]), params, method='L-BFGS-B')
# Out:
#       fun: 1.9719467942108008e-10
#  hess_inv: <15x15 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 2.58088106e-13, -1.68260539e-07,  2.03084268e-07, -3.29915817e-14,
#        -2.82366600e-07, -9.12958975e-06, -9.35946365e-06,  5.37335553e-06,
#        -3.79367659e-06, -1.23703310e-07,  1.89681302e-07, -1.23598343e-07,
#        -1.29350368e-13, -1.54501829e-13, -2.21216530e-13])
#   message: b'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 272
#       nit: 8
#    status: 0
#   success: True
#         x: array([-3.02007643e-04, -1.12120444e-01,  4.93856674e-03, -2.37786788e-02,
#         2.34361988e+00,  2.60772515e-02,  7.46004651e-03, -1.45827505e+00,
#         2.04234497e-01,  1.66953114e-02,  2.65574575e+00, -6.16405169e-02,
#         7.04911607e-03,  2.66710433e-03, -2.07188766e-02])

# %%
partial_trace(list(wf_sim.wavefunction(sp_network(result['x']))))
# Out:
# array([[0.47929859+0.j        , 0.01032374-0.01118915j],
#        [0.01032374+0.01118915j, 0.52070141+0.j        ]])

# %%
rhos[0]
# Out:
# array([[0.47929711+0.j       , 0.0103298 -0.0112017j],
#        [0.0103298 +0.0112017j, 0.52070289+0.j       ]])

# %% [markdown]
# ### Training

# %%
cost_train_list = []
cost_test_list = []
i = 0

# %%
params_list = []
cost_list = []
functional_list = []
n_iters = n_iters_max

for i, rho in enumerate(rhos):
    print("\n\n~~~~~~~~~~~~~~~~~~~~~~ Density Matrix {}/{} ~~~~~~~~~~~~~~~~~~~~~~\n".format(i+1, len(rhos)))
    print("Functional: {:.7f}\n\n".format(purity_fct(rho)))

    result = minimize(lambda params: cost(params, rho), params, method='L-BFGS-B')
    params_predict = result['x']
    curr_cost = result['fun']
    curr_functional = purity_fct(get_rho(params_predict))
    
    params_list.append(params_predict)
    cost_list.append(curr_cost)
    functional_list.append(curr_functional)
    
    print('\nCost: {: .7f} −− Functional: {:.7f}'.format(cost_list[-1], functional_list[-1]))
    
    params = params_predict # we change the initialization for the next step
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 1/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5013216
#
#
#
# Cost:  0.0000000 −− Functional: 0.5013207
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 2/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5050119
#
#
#
# Cost:  0.0000000 −− Functional: 0.5050110
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 3/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5003756
#
#
#
# Cost:  0.0000000 −− Functional: 0.5003755
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 4/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5000793
#
#
#
# Cost:  0.0000000 −− Functional: 0.5000792
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 5/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5062566
#
#
#
# Cost:  0.0000000 −− Functional: 0.5062568
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 6/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5026189
#
#
#
# Cost:  0.0000000 −− Functional: 0.5026189
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 7/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5027923
#
#
#
# Cost:  0.0000000 −− Functional: 0.5027916
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 8/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5006246
#
#
#
# Cost:  0.0000000 −− Functional: 0.5006244
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 9/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5115329
#
#
#
# Cost:  0.0000000 −− Functional: 0.5115323
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 10/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5150565
#
#
#
# Cost:  0.0000000 −− Functional: 0.5150564
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 11/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5190205
#
#
#
# Cost:  0.0000000 −− Functional: 0.5190201
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 12/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5108548
#
#
#
# Cost:  0.0000000 −− Functional: 0.5108549
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 13/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5179587
#
#
#
# Cost:  0.0000000 −− Functional: 0.5179577
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 14/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5122447
#
#
#
# Cost:  0.0000000 −− Functional: 0.5122438
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 15/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5104410
#
#
#
# Cost:  0.0000000 −− Functional: 0.5104414
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 16/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5103413
#
#
#
# Cost:  0.0000000 −− Functional: 0.5103405
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 17/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5214127
#
#
#
# Cost:  0.0000000 −− Functional: 0.5214127
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 18/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5296434
#
#
#
# Cost:  0.0000000 −− Functional: 0.5296440
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 19/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5256831
#
#
#
# Cost:  0.0000000 −− Functional: 0.5256804
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 20/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5281683
#
#
#
# Cost:  0.0000000 −− Functional: 0.5281662
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 21/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5209202
#
#
#
# Cost:  0.0000000 −− Functional: 0.5209195
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 22/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5211796
#
#
#
# Cost:  0.0000000 −− Functional: 0.5211778
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 23/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5286231
#
#
#
# Cost:  0.0000000 −− Functional: 0.5286228
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 24/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5210143
#
#
#
# Cost:  0.0000000 −− Functional: 0.5210154
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 25/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5312870
#
#
#
# Cost:  0.0000000 −− Functional: 0.5312880
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 26/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5315410
#
#
#
# Cost:  0.0000000 −− Functional: 0.5315409
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 27/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5320927
#
#
#
# Cost:  0.0000000 −− Functional: 0.5320943
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 28/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5307376
#
#
#
# Cost:  0.0000000 −− Functional: 0.5307365
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 29/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5304279
#
#
#
# Cost:  0.0000000 −− Functional: 0.5304281
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 30/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5337345
#
#
#
# Cost:  0.0000000 −− Functional: 0.5337343
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 31/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5369510
#
#
#
# Cost:  0.0000000 −− Functional: 0.5369503
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 32/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5311380
#
#
#
# Cost:  0.0000000 −− Functional: 0.5311382
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 33/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5482950
#
#
#
# Cost:  0.0000000 −− Functional: 0.5482958
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 34/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5452475
#
#
#
# Cost:  0.0000000 −− Functional: 0.5452500
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 35/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5492456
#
#
#
# Cost:  0.0000000 −− Functional: 0.5492456
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 36/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5408964
#
#
#
# Cost:  0.0000000 −− Functional: 0.5408966
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 37/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5428787
#
#
#
# Cost:  0.0000000 −− Functional: 0.5428789
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 38/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5427031
#
#
#
# Cost:  0.0000000 −− Functional: 0.5427031
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 39/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5476389
#
#
#
# Cost:  0.0000000 −− Functional: 0.5476382
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 40/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5415783
#
#
#
# Cost:  0.0000000 −− Functional: 0.5415802
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 41/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5519799
#
#
#
# Cost:  0.0000000 −− Functional: 0.5519805
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 42/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5503938
#
#
#
# Cost:  0.0000000 −− Functional: 0.5503880
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 43/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5518101
#
#
#
# Cost:  0.0000000 −− Functional: 0.5518101
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 44/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5552591
#
#
#
# Cost:  0.0000000 −− Functional: 0.5552590
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 45/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5582830
#
#
#
# Cost:  0.0000000 −− Functional: 0.5582847
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 46/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5574275
#
#
#
# Cost:  0.0000000 −− Functional: 0.5574279
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 47/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5554785
#
#
#
# Cost:  0.0000000 −− Functional: 0.5554786
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 48/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5575572
#
#
#
# Cost:  0.0000000 −− Functional: 0.5575571
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 49/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5611923
#
#
#
# Cost:  0.0000000 −− Functional: 0.5611922
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 50/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5685558
#
#
#
# Cost:  0.0000000 −− Functional: 0.5685559
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 51/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5659031
#
#
#
# Cost:  0.0000000 −− Functional: 0.5659029
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 52/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5647906
#
#
#
# Cost:  0.0000000 −− Functional: 0.5647954
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 53/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5664084
#
#
#
# Cost:  0.0000000 −− Functional: 0.5664101
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 54/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5607860
#
#
#
# Cost:  0.0000000 −− Functional: 0.5607808
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 55/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5622860
#
#
#
# Cost:  0.0000000 −− Functional: 0.5622859
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 56/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5693379
#
#
#
# Cost:  0.0000000 −− Functional: 0.5693387
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 57/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5707724
#
#
#
# Cost:  0.0000000 −− Functional: 0.5707749
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 58/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5754789
#
#
#
# Cost:  0.0000000 −− Functional: 0.5754791
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 59/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5723912
#
#
#
# Cost:  0.0000000 −− Functional: 0.5723970
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 60/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5784110
# Cost:  0.0000000 −− Functional: 0.5784117
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 61/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5790505
#
#
#
# Cost:  0.0000000 −− Functional: 0.5790528
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 62/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5730195
#
#
#
# Cost:  0.0000000 −− Functional: 0.5730192
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 63/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5759627
#
#
#
# Cost:  0.0000000 −− Functional: 0.5759639
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 64/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5775783
#
#
#
# Cost:  0.0000000 −− Functional: 0.5775810
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 65/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5855850
#
#
#
# Cost:  0.0000000 −− Functional: 0.5855853
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 66/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5810209
#
#
#
# Cost:  0.0000000 −− Functional: 0.5810207
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 67/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5852190
#
#
#
# Cost:  0.0000000 −− Functional: 0.5852188
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 68/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5818998
#
#
#
# Cost:  0.0000000 −− Functional: 0.5819016
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 69/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5858706
#
#
#
# Cost:  0.0000000 −− Functional: 0.5858708
#
#
# ~~~~~~~~~~~~~~~~~~~~~~ Density Matrix 70/400 ~~~~~~~~~~~~~~~~~~~~~~
#
# Functional: 0.5821727
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-128-6d780a8aa1cd> in <module>
#       8     print("Functional: {:.7f}\n\n".format(purity_fct(rho)))
#       9
# ---> 10     result = minimize(lambda params: cost(params, rho), params, method='L-BFGS-B')
#      11     params_predict = result['x']
#      12     curr_cost = result['fun']
#
# ~/miniconda3/envs/pyquil/lib/python3.7/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     599     elif meth == 'l-bfgs-b':
#     600         return _minimize_lbfgsb(fun, x0, args, jac, bounds,
# --> 601                                 callback=callback, **options)
#     602     elif meth == 'tnc':
#     603         return _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#
# ~/miniconda3/envs/pyquil/lib/python3.7/site-packages/scipy/optimize/lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, **unknown_options)
#     333             # until the completion of the current minimization iteration.
#     334             # Overwrite f and g:
# --> 335             f, g = func_and_grad(x)
#     336         elif task_str.startswith(b'NEW_X'):
#     337             # new iteration
#
# ~/miniconda3/envs/pyquil/lib/python3.7/site-packages/scipy/optimize/lbfgsb.py in func_and_grad(x)
#     279         def func_and_grad(x):
#     280             f = fun(x, *args)
# --> 281             g = _approx_fprime_helper(x, fun, epsilon, args=args, f0=f)
#     282             return f, g
#     283     else:
#
# ~/miniconda3/envs/pyquil/lib/python3.7/site-packages/scipy/optimize/optimize.py in _approx_fprime_helper(xk, f, epsilon, args, f0)
#     668         ei[k] = 1.0
#     669         d = epsilon * ei
# --> 670         grad[k] = (f(*((xk + d,) + args)) - f0) / d[k]
#     671         ei[k] = 0.0
#     672     return grad
#
# ~/miniconda3/envs/pyquil/lib/python3.7/site-packages/scipy/optimize/optimize.py in function_wrapper(*wrapper_args)
#     298     def function_wrapper(*wrapper_args):
#     299         ncalls[0] += 1
# --> 300         return function(*(wrapper_args + args))
#     301
#     302     return ncalls, function_wrapper
#
# <ipython-input-128-6d780a8aa1cd> in <lambda>(params)
#       8     print("Functional: {:.7f}\n\n".format(purity_fct(rho)))
#       9
# ---> 10     result = minimize(lambda params: cost(params, rho), params, method='L-BFGS-B')
#      11     params_predict = result['x']
#      12     curr_cost = result['fun']
#
# <ipython-input-123-dc0a9ace8935> in cost(params, rho_input)
#       1 def cost(params, rho_input):
# ----> 2     rho_output = get_rho(params)
#       3
#       4     return trace_distance(rho_output, rho_input) + functional_reg * purity_mse(rho_output, rho_input)
#
# <ipython-input-122-4d9a8f995b1b> in get_rho(params)
#       2     circuit = sp_network(params)
#       3     state = list(wf_sim.wavefunction(circuit))
# ----> 4     rho_output = partial_trace(state)
#       5
#       6     return rho_output
#
# <ipython-input-106-4d20a3a51c88> in partial_trace(state)
#       3              + state[1] * qutip.states.ket([0,1]) \
#       4              + state[2] * qutip.states.ket([1,0]) \
# ----> 5              + state[3] * qutip.states.ket([1,1])
#       6     rho_output = np.array(qstate.ptrace(1).data.todense())
#       7     return rho_output
#
# ~/miniconda3/envs/pyquil/lib/python3.7/site-packages/qutip/states.py in ket(seq, dim)
#     638         dim = [dim] * len(seq)
#     639     return tensor([basis(dim[i], _character_to_qudit(x))
# --> 640                    for i, x in enumerate(seq)])
#     641
#     642
#
# ~/miniconda3/envs/pyquil/lib/python3.7/site-packages/qutip/states.py in <listcomp>(.0)
#     638         dim = [dim] * len(seq)
#     639     return tensor([basis(dim[i], _character_to_qudit(x))
# --> 640                    for i, x in enumerate(seq)])
#     641
#     642
#
# ~/miniconda3/envs/pyquil/lib/python3.7/site-packages/qutip/states.py in basis(N, n, offset)
#     109     ptr = np.array([0]*((n - offset)+1)+[1]*(N-(n-offset)),dtype=np.int32)
#     110
# --> 111     return Qobj(fast_csr_matrix((data,ind,ptr), shape=(N,1)), isherm=False)
#     112
#     113
#
# ~/miniconda3/envs/pyquil/lib/python3.7/site-packages/qutip/qobj.py in __init__(self, inpt, dims, shape, type, isherm, copy, fast, superrep, isunitary)
#     234             return
#     235
# --> 236         if isinstance(inpt, Qobj):
#     237             # if input is already Qobj then return identical copy
#     238
#
# KeyboardInterrupt:
